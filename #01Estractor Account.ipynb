# %%
#import libraries you will need
import os
import tweepy as tw
import pandas as pd
import json
import numpy as np      # For number computing
from IPython.display import display
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
from textblob import TextBlob
import re

# %%
#Autenticación de claves
consumer_key="consumer_secret="access_token="access_token_secret="

# %%
#Autorización a usar las claves de acceso a mi tweeter
auth= tw.OAuthHandler(consumer_key,consumer_secret)
auth.set_access_token(access_token,access_token_secret)
api = tw.API(auth, wait_on_rate_limit=True)

# %%
#obtener información de perfil de otro usuario
data=api.get_user("PrimeVideoLat")
print (json.dumps (data._json, indent=2))
# Out:
# {
#   "id": 1193991063209304064,
#   "id_str": "1193991063209304064",
#   "name": "Amazon Prime Video Latinoam\u00e9rica",
#   "screen_name": "PrimeVideoLat",
#   "location": "Latinoam\u00e9rica",
#   "profile_location": null,
#   "description": "La p\u00e1gina oficial de Amazon Prime Video Latinoam\u00e9rica en Twitter.",
#   "url": null,
#   "entities": {
#     "description": {
#       "urls": []
#     }
#   },
#   "protected": false,
#   "followers_count": 119692,
#   "friends_count": 9,
#   "listed_count": 88,
#   "created_at": "Mon Nov 11 20:37:15 +0000 2019",
#   "favourites_count": 1079,
#   "utc_offset": null,
#   "time_zone": null,
#   "geo_enabled": false,
#   "verified": true,
#   "statuses_count": 2437,
#   "lang": null,
#   "status": {
#     "created_at": "Sun Jul 05 23:04:47 +0000 2020",
#     "id": 1279914147774443520,
#     "id_str": "1279914147774443520",
#     "text": "@josejoiys https://t.co/1sXNSBZEh1",
#     "truncated": false,
#     "entities": {
#       "hashtags": [],
#       "symbols": [],
#       "user_mentions": [
#         {
#           "screen_name": "josejoiys",
#           "name": "Jose Bascu\u00f1an",
#           "id": 55080173,
#           "id_str": "55080173",
#           "indices": [
#             0,
#             10
#           ]
#         }
#       ],
#       "urls": [],
#       "media": [
#         {
#           "id": 1279914136399482881,
#           "id_str": "1279914136399482881",
#           "indices": [
#             11,
#             34
#           ],
#           "media_url": "http://pbs.twimg.com/tweet_video_thumb/EcMrIDMXkAECqNB.jpg",
#           "media_url_https": "https://pbs.twimg.com/tweet_video_thumb/EcMrIDMXkAECqNB.jpg",
#           "url": "https://t.co/1sXNSBZEh1",
#           "display_url": "pic.twitter.com/1sXNSBZEh1",
#           "expanded_url": "https://twitter.com/PrimeVideoLat/status/1279914147774443520/photo/1",
#           "type": "photo",
#           "sizes": {
#             "thumb": {
#               "w": 150,
#               "h": 150,
#               "resize": "crop"
#             },
#             "large": {
#               "w": 454,
#               "h": 256,
#               "resize": "fit"
#             },
#             "small": {
#               "w": 454,
#               "h": 256,
#               "resize": "fit"
#             },
#             "medium": {
#               "w": 454,
#               "h": 256,
#               "resize": "fit"
#             }
#           }
#         }
#       ]
#     },
#     "extended_entities": {
#       "media": [
#         {
#           "id": 1279914136399482881,
#           "id_str": "1279914136399482881",
#           "indices": [
#             11,
#             34
#           ],
#           "media_url": "http://pbs.twimg.com/tweet_video_thumb/EcMrIDMXkAECqNB.jpg",
#           "media_url_https": "https://pbs.twimg.com/tweet_video_thumb/EcMrIDMXkAECqNB.jpg",
#           "url": "https://t.co/1sXNSBZEh1",
#           "display_url": "pic.twitter.com/1sXNSBZEh1",
#           "expanded_url": "https://twitter.com/PrimeVideoLat/status/1279914147774443520/photo/1",
#           "type": "animated_gif",
#           "sizes": {
#             "thumb": {
#               "w": 150,
#               "h": 150,
#               "resize": "crop"
#             },
#             "large": {
#               "w": 454,
#               "h": 256,
#               "resize": "fit"
#             },
#             "small": {
#               "w": 454,
#               "h": 256,
#               "resize": "fit"
#             },
#             "medium": {
#               "w": 454,
#               "h": 256,
#               "resize": "fit"
#             }
#           },
#           "video_info": {
#             "aspect_ratio": [
#               227,
#               128
#             ],
#             "variants": [
#               {
#                 "bitrate": 0,
#                 "content_type": "video/mp4",
#                 "url": "https://video.twimg.com/tweet_video/EcMrIDMXkAECqNB.mp4"
#               }
#             ]
#           }
#         }
#       ]
#     },
#     "source": "<a href=\"https://mobile.twitter.com\" rel=\"nofollow\">Twitter Web App</a>",
#     "in_reply_to_status_id": 1279911747797880833,
#     "in_reply_to_status_id_str": "1279911747797880833",
#     "in_reply_to_user_id": 55080173,
#     "in_reply_to_user_id_str": "55080173",
#     "in_reply_to_screen_name": "josejoiys",
#     "geo": null,
#     "coordinates": null,
#     "place": null,
#     "contributors": null,
#     "is_quote_status": false,
#     "retweet_count": 1,
#     "favorite_count": 3,
#     "favorited": false,
#     "retweeted": false,
#     "possibly_sensitive": false,
#     "lang": "und"
#   },
#   "contributors_enabled": false,
#   "is_translator": false,
#   "is_translation_enabled": false,
#   "profile_background_color": "F5F8FA",
#   "profile_background_image_url": null,
#   "profile_background_image_url_https": null,
#   "profile_background_tile": false,
#   "profile_image_url": "http://pbs.twimg.com/profile_images/1268559979503661056/zsDx1fwC_normal.jpg",
#   "profile_image_url_https": "https://pbs.twimg.com/profile_images/1268559979503661056/zsDx1fwC_normal.jpg",
#   "profile_banner_url": "https://pbs.twimg.com/profile_banners/1193991063209304064/1593147638",
#   "profile_link_color": "1DA1F2",
#   "profile_sidebar_border_color": "C0DEED",
#   "profile_sidebar_fill_color": "DDEEF6",
#   "profile_text_color": "333333",
#   "profile_use_background_image": true,
#   "has_extended_profile": false,
#   "default_profile": true,
#   "default_profile_image": false,
#   "following": true,
#   "follow_request_sent": false,
#   "notifications": false,
#   "translator_type": "none"
# }

# %%
def twitter_setup():
    """
    Utility function to setup the Twitter's API
    with our access keys provided.
    """
    # Authentication and access using keys:
    auth = tw.OAuthHandler(consumer_key, consumer_secret)
    auth.set_access_token(access_token,access_token_secret)

    # Return API with authentication:
    api = tw.API(auth)
    return api

# %%
# We create an extractor object:
extractor = twitter_setup()

# We create a tweet list as follows:
tweets = extractor.user_timeline(screen_name="PrimeVideoLat", count=500)
print("Number of tweets extracted: {}.\n".format(len(tweets)))

# We print the most recent 5 tweets:
print("5 recent tweets:\n")
for tweet in tweets[:500]:
    print(tweet.text)
    print()
# Out:
# Number of tweets extracted: 200.
#
# 5 recent tweets:
#
# @josejoiys https://t.co/1sXNSBZEh1
#
# @OmarLeeOficial https://t.co/G3GALkYuUi
#
# @CDarioRodriguez Drama: Little Fires Everywhere
# Ciencia ficción: Tales from the Loop
# Amor: Modern Love
#
# @_salvapantallas https://t.co/j3x7GE08Ax
#
# @SILVAELIAS_ ¿Quien es exactamente?
#
# —¿Cuál es tu sueño?
# —Poder dormir antes de las 12 después de iniciar un maratón de Star Wars.
# —Nadie lo ha logrado nunca. 🙄
#
# @jjimmybass ¿la empezamos hoy?
#
# @oleicymar Esa es la mejor respuesta. ❤️
#
# @guadapavon_ @Deivid_pela 🤩
#
# @AngelitoSvr https://t.co/QLHwQdONrV
#
# @ay_Lola Creo que es sentimiento que a todos nos da con estrenos como este. 😎
#
# @moisesdenis11 https://t.co/OvNCJqCIiX
#
# @afalcon89 Es una buena opción para hacer maratón. 🤩
#
# @Didakusalex Yo creo que más bien ya deberías tenerla. 😎
#
# @gotechhost El sentimiento siempre será mutuo. 💕
#
# @guadapavon_ @Deivid_pela ¿La vamos a empezar hoy?
#
# @marianadaria 😊 vas hacer que me sonroje.
#
# @Marcos_Adrian9 No es lo mejor leer el: "ya esta disponible". 🤩
#
# Una serie de época 🤝 personajes contemporáneos.
# ¿Les suena familiar?
# #MadMen ya está disponible.… https://t.co/5Vioe41snI
#
# @FraaanYork 5 días para el gran estreno.
#
# @Roesteban_ Estamos a sólo unos días del estreno.
#
# @Aandrespodadera Hoy empieza la cuenta regresiva. 🙌
#
# @Manuel72Jose Sí, es buenaza.
#
# @benjamedina85 https://t.co/BSYT213XPS
#
# @maria_mfed https://t.co/djNFrnh6I2
#
# @RodriAlb0zu388 https://t.co/DQVEtBnw8e
#
# @cmsampayo Buenaza.
#
# @SicMvndvsCE https://t.co/ookla4JEOn
#
# @Jesusdpb Se ve que se divirtió horrores haciéndola.
#
# @CVALDES76 Bueno, es que es inolvidable como Bane.
#
# @Darocalderon1 Eres el único que la ha mencionado y es una gran cinta.
#
# @maiconauta https://t.co/UGVrjtZT3S
#
# @HidalgoRandy Bane, sí, totalmente de acuerdo.
#
# @Patriciamv3 Ay, ¿hola?
#
# @Hamblet Es más músculo que persona en esa.
#
# @MJavier21 Uf, es que Bane es el mejor de los enemigos de Batman.
#
# @JuanAlejoTH ¿Locke no te gusta?
#
# @AngelaMachad0 https://t.co/aXL2DvhoJu
#
# @gonzo_pi Bane, el único enemigo que ha podido con Batman en cómics y en el cine.
#
# @Nightwing2mil3 ¿Qué? No acabo de leer esto... bueno, el hecho real es que todos están increíbles, hasta los malos,… https://t.co/DvTRP9IMcw
#
# @andrewaurea Es el mejor Bane, si me preguntan.
#
# @queporcion Es el mejor Bane después del cómic.
#
# @Neldorwen Praetor Shinzom, nadie se acuerda de esas cosas. 5 de 5 estrellas te llevas.
#
# @ojimenez19 No, es la primera que me vino a la mente, ¿cuál es la tuya?
#
# @pattroncoso96 https://t.co/QsAYku9mzV
#
# @Da_Alexander96 Todos están espectaculares, pero sí, sobresale él.
#
# @victorahumada10 Es de sus mejores cintas.
#
# @mrsnanmibia No hay mentira en esta respuesta. https://t.co/2mYUhwOjuQ
#
# @jaimejcarrasco Sí, qué bien sale ahí.
#
# @Hu60arieL Es una masa de puro músculo y la mejor versión de Bane. https://t.co/6BAWCLUPnF
#
# @maferchalo Vaya que lo hace bien.
#
# La primera es... Dunkirk https://t.co/Ja51mAIv6H
#
# @alejandroduque8 7500, aunque técnicamente se debería de pronunciar: siete, cinco, cero, cero. Es un código.
#
# @MiguelAngelZ8 Con gusto, ¿ya viste Troop Zero?
#
# @Gonzalo267 Me cuentas qué te pareció.
#
# @cosasduIces No digas eso, eres la mejor, Guillermina.
#
# @Alfredoprieto4 Me tenía súper tenso, pero es muy buena.
#
# @MikhailJesua Gracias, sí que lo es.
#
# ¿Por qué Joseph Gordon-Levitt luce preocupado? ¿Por qué tiene sangre en la camisa? Esas y otras preguntas serán res… https://t.co/wKunNuxxJS
#
# @adrianaschet de nada 😎
#
# @pabloculellok @dlerer Voy a dejar esto por aquí:
# https://t.co/A5yXFFzy99
#
# @dlerer @pabloculellok Nada de confusiones, aquí lo tienes. 😎
# https://t.co/A5yXFFzy99
#
# @adrianaschet @dlerer @pabloculellok Dejare esto por aquí:
# https://t.co/A5yXFFzy99
#
# @adrianaschet @dlerer @pabloculellok Claro que no. Aquí esta para ti.
# https://t.co/A5yXFFzy99
# ❤️
#
# Si yo me encontrara a Reese Witherspoon y Kerry Washington también les pediría una foto tan linda como esta. https://t.co/ngkFXjRPIr
#
# @sh4d1t0 @HolisLely @Blackaletwo @NetflixLAT @natsberistain Completitas https://t.co/LwdZhUzqCs
#
# @Nanaacho Es que hasta la pregunta ofende.
#
# @BGambin 🍿+ 🍕 + 🧋 = Viendo Hanna segunda temporada.
#
# @BGambin ¿Ya empezaste la segunda temporada?
#
# @MontanezMarcio Este es nuestro momento, no se diga más. 😎
#
# @mati_sanchez97 Me parece un gran plan. 😎
#
# @MontanezMarcio No sientes que la trama es de lo más adictiva. 🤩
#
# @mati_sanchez97 ¿Ya la empezaste a ver?
#
# #Hanna está de vuelta y yo estoy así:
# Nueva temporada, ya disponible. https://t.co/MxLSaVoiAE https://t.co/hd6CdBf7b3
#
# @_noefarias ¿empezamos hoy?
#
# @ElOtroDaVinci https://t.co/bMhEc6Zs8Q
#
# @AngelDuoc Eso es un clásico. 😎
#
# @VeronicaPM Con quién te quedas ¿Mia o Elena?
#
# Cuando quieres usar la credencial del cole para entrar a la disco.¿Qué otra hazaña intentaron con ese papel plastif… https://t.co/JOdxQ3CFdc
#
# @MateOE_ Empezamos hoy el maratón, ¿no?
# Mientras comemos.
#
# @mlinarescruz @PrimeVideoMX See you soon! 🤩
#
# @ShallowYami Más que bien. ¿no crees? 😍
#
# @Moralitos14 https://t.co/igOCZZ1Ias
#
# @UnluckyBSTRD @diegoluna_ @PrimeVideoMX @corrientegolfo Estamos más que listos. 🤩
#
# @M_Diaz_7z @diegoluna_ @PrimeVideoMX @corrientegolfo https://t.co/FQ0RKJsmjj
#
# En esta mesa se habla de todo. Pan y Circo con Diego Luna, muy pronto en Amazon Prime Video. https://t.co/GQQ8okD0ei
#
# ¿Quién es su personaje favorito de Modern Family y por qué Phil? https://t.co/XysEwHc543
#
# @evigueras7 Listo, a darle que hay mucho que maratonear.
#
# @wilmar__84 https://t.co/ii7KRVETmL
#
# @PatriMS1 Mejor serie de la historia. https://t.co/yYcVxdXQz9
#
# @claudyodaniel https://t.co/GVX84P62Fw
#
# @freddyvcp ¡Ma-ra-tón! ¿Con cuál empiezas? Mi favorita es... https://t.co/Wn3aArjDGu
#
# @JoseLuiGrc ¡Gracias!
#
# @AMatosIsAnAngel https://t.co/Y0TSuiRdPA
#
# @ferchop12_05 https://t.co/uw4GtZKKKP
#
# @Marco_V_A_A https://t.co/2mysJdN6dw
#
# @Pupy7u71 ¡Gracias!
#
# @jose_metal6 Eres bienvenido cuando quieras.
#
# @decamiloleon ¡Emoción total! https://t.co/rVtS7zrUTv
#
# @kingale26 https://t.co/7eTtMebG2x
#
# @douza_lilu Awwww, amo verlos felices.
#
# @MrGutty @SonsofAnarchy Es la mejor serie. Que la disfrutes.
#
# @evigueras7 Cuánto cariño. Que la disfrutes. https://t.co/Wl3hMl9ffd
#
# @LasTeclasDNegro Scully, es la mejor. https://t.co/0N4GM9jOHe
#
# @ViteAC_ Awww, gracias.
#
# @Marito_OC https://t.co/vkv6M7DFYN
#
# @leonarditofrio Gracias, Leonardo. Tú sí sabes.
#
# @saulcorrales3 Esos son maratones.
#
# @DiegoARG89 Súper recomendadas. Que te hagan caso todos.
#
# @pitgonzalez_76 La mejor serie de todos los tiempos. https://t.co/EJ3b9Iyr4i
#
# @danisanOk Va a ser un gran mes, sí. Gracias, Daniel.
#
# @elflechasverde @PrimeVideo ¿Con cuál empiezas el maratón?
#
# @MontanezMarcio Ya casi... https://t.co/ePDeBQW5KJ
#
# Una tonelada de series y películas favoritas para todos los gustos. Eso son los estrenos de este mes. https://t.co/QbhwKFBKTG
#
# @SzuritaOficial @justinabus @AriasPJuanita @robtalcual @pamohpam @octavio_hm @TatisAlexander @AquelSantini @LuGomezRobledo
#
# Mi yo interno es muy cruel. #CómoSobrevivirSoltero https://t.co/gJr5gIIV5C
#
# @stefaniapepiice Awww, gracias, es mutuo.
#
# @_haroldjosue Todo bien, se vale buscar una segunda opinión.
#
# @MarianitoSL ¡Entra! ¿Te toca maratón esta noche?
#
# @LoliAmran Sí que lo es, ¿la piensas volver a ver desde la primera temporada? Porque yo sí.
#
# @Miguel78458572 De nada, Miguel.
#
# @joseRDV99 Oye, muchas gracias. ¿Ya la metiste en tu watchlist?
#
# @anderthenite Awww, sí, totalmente.
#
# @Toni_Chavez Y a todos los espero con los brazos abiertos.
#
# @ColoresDice ¿A cuál de los dos prefieres?
#
# ¡Dexter ya está disponible! Hice este mashup por si alguien se confundió de Dexter, para que no extrañen.… https://t.co/VdYlftFGjo
#
# @Myrtaabcd @SzuritaOficial @justinabus @AriasPJuanita @robtalcual @pamohpam @octavio_hm @TatisAlexander… https://t.co/zOVSPKUe1E
#
# @DanRo1992 @SzuritaOficial @justinabus @AriasPJuanita @robtalcual @pamohpam @octavio_hm @TatisAlexander… https://t.co/pG77Iw6sr0
#
# @Usuario74285 @SzuritaOficial @justinabus @AriasPJuanita @robtalcual @pamohpam @octavio_hm @TatisAlexander… https://t.co/9ifFvr9PuB
#
# @djrm96 @SzuritaOficial @justinabus @AriasPJuanita @robtalcual @pamohpam @octavio_hm @TatisAlexander @AquelSantini… https://t.co/7aS8UYWiGI
#
# @marialepm13 Por hacernos tan feliz. 😍
#
# Es aquí donde se etiqueta al amigo que es tercera rueda, el que se apresura con las citas o, bueno, al que lo hace… https://t.co/DwjNmilwkv
#
# @ANGELTTT1 No hay sopa para ti. 😂
#
# @ismael_llamadme 🦄🤣
#
# @Uschimusic https://t.co/A9Tyw2lmDU
#
# @nicoscalzo Como olvidar eso. 😂
#
# @pri_carnero No, no, no. 🤣
#
# @Penquista_ The Soup Nazi
#
# @Alejand42477570 The soup Nazi se lleva el premio diría yo.
#
# @paulithreepwood 🤣😉⭐️
#
# @unvestidounamor El pony 🦄
#
# @LoliAmran 😍😍😍😍
#
# @moisesdenis11 https://t.co/inKcAFC8BD
#
# @Dennisantamaria Eso es memorable. 😍
#
# @Uschimusic Es una dulce y bendita obsesión. 😍
#
# @SolcitoPug Claro que lo es. 😂
#
# @wilics Claro, no tenia ese episodio tan presente. 😅
#
# @AntiReferente https://t.co/EiMinJognz
#
# @mario351 @TeguaTitulado No puedo parar de reír solo de recordarlo.
#
# @TeguaTitulado @elaguanterojo_ Claro que lo es.
# ⭐️⭐️⭐️⭐️⭐️
#
# @yderepente ⭐️⭐️⭐️⭐️⭐️
#
# @federicobaraya Es uno de los buenos.
#
# @MichaelRomeroR Looking for the quotes. Gotta check the quotes. Love a good quote.
#
# @pegajoso_23 🤣😅🤣😅
#
# @pegajoso_23 https://t.co/0Ei9Avf9fY
#
# @lucasgrt09 @aioigzo https://t.co/cj6YZkPAN1
#
# @aioigzo Más bien es para que tengas con que distraerte.
#
# @Alejoesca https://t.co/sM2dTSEGsB
#
# @AleGonna Es un decisión difícil, lo sé.
#
# @kingale26 If every instinct you have is wrong, then the opposite would have to be right. 😅
#
# @yderepente ¿no recuerdas dónde fue que quedo?
#
# @nurysdeli No soup for you! 🤣
#
# @AvenenteLucas Es algo indudable. 😂
#
# @belitoarg Son tantos que la elección se vuelve difícil.
#
# @elaguanterojo_ @TeguaTitulado Es una cuestión de risas interminables. 🤣
#
# @sammydavistunka El pony eso algo que no se puede olvidar. 😅
#
# @jul_i Es uno de los favoritos de eso no hay duda.
#
# @YAZZ9000 Es tan bueno.
#
# @lucasgrt09 🤣❤️😅😂
#
# @ACalderas Sería difícil decir lo contrario.
#
# @hazpiri La mejor cita: George: Do you ever get down on your knees and thank God you know me and have access to my dementia?
#
# @elfumateiro Claro que lo es. 😂
#
# @A_Ruizdeolano The Chicken rouster es algo hilarante. 😂
#
# @CachaCacciabue Es uno de los buenos. 😅
#
# @neutroweb Es nuestro favorito de siempre. ❤️
#
# @Lettus_Maglio La venganza de Elaine. 😂😂🤣
#
# @giuli_zampa En un resumen de la primera a la quinta temporada es uno de los buenos.
#
# @leosanca78 Es un gran momento. 🤣
#
# @pegajoso_23 Siempre existe la opción de volverla a ver. 🤪
#
# @polytheneval The Jacket 😂🔥💎
#
# @gdmiazzo Claro, es uno de los buenos.
#
# @gonzalito_olav Creo que votare por el restaurante chino.
#
# Estoy harto de esta discusión sobre Seinfeld, así es que lo haremos oficial. https://t.co/Cr3b1IEN7q
#
# @mri_xsy Es lo mejor. 🤩
#
# @Bevydubon Veremos que se convertirá en tu gran amor. 💓
#
# @Tufantasmita En sus marcas, listos, fuera. 🤩
#
# @Danovuna Entendemos que el amor es universal:  ❤️🧡💛💚💙💜🤎🖤🤍
#
# @toledocai Aquí la programación también es de todos los colores. 🌈
#
# @Tufantasmita Esa es la mejor decisión. 👏
#
# Nueva ciudad, nuevas historias y caras familiares.
# The L Word: Generation Q ya está disponible.… https://t.co/qBCpiFa7Go
#
# @ChronosVenom No hay nada que agradecer. ❤️
#
# @maferchalo Lo importante es que sólo es cuestión de días. 🤩
#
# @YDaysG 🤩
#
# @Textileano Ya estamos muy cerca. 🤩
#
# @Elva_kbana Son la mejores historias de amor. ¿Cuál fue tu historia favorita? 😍
#
# @andybarbaro Tienes muy buen gusto. 😎
#
# En marketing no van a estar muy contentos con Stormfront por esto. https://t.co/3IQw7FOuzO
#
# @bam_bammx @odioapancho Oh, no. Las estafaron.
#
# Sandra, Kate y sus secuaces roban 128 millones de dólares y se entretienen con burbujas. Es como tu gato y la caja… https://t.co/3FMpjdO79h
#
# @NoTime2Design ¡Que emoción!
#
# Nos encanta que estés satisfecho. 😁
#
# ^KZ

# %%
# We create a pandas dataframe as follows:
data = pd.DataFrame(data=[tweet.text for tweet in tweets], columns=['Tweets'])

# We display the first 10 elements of the dataframe:
display(data.head(5))
# Out:
#                                               Tweets
# 0                 @josejoiys https://t.co/1sXNSBZEh1
# 1            @OmarLeeOficial https://t.co/G3GALkYuUi
# 2  @CDarioRodriguez Drama: Little Fires Everywher...
# 3           @_salvapantallas https://t.co/j3x7GE08Ax
# 4                @SILVAELIAS_ ¿Quien es exactamente?

# %%
# Internal methods of a single tweet object:
print(dir(tweets[0]))
# Out:
# ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', '_api', '_json', 'author', 'contributors', 'coordinates', 'created_at', 'destroy', 'entities', 'extended_entities', 'favorite', 'favorite_count', 'favorited', 'geo', 'id', 'id_str', 'in_reply_to_screen_name', 'in_reply_to_status_id', 'in_reply_to_status_id_str', 'in_reply_to_user_id', 'in_reply_to_user_id_str', 'is_quote_status', 'lang', 'parse', 'parse_list', 'place', 'possibly_sensitive', 'retweet', 'retweet_count', 'retweeted', 'retweets', 'source', 'source_url', 'text', 'truncated', 'user']

# %%
# We print info from the first tweet:
print(tweets[0].id)
print(tweets[0].created_at)
print(tweets[0].source)
print(tweets[0].favorite_count)
print(tweets[0].retweet_count)
print(tweets[0].geo)
print(tweets[0].coordinates)
print(tweets[0].entities)
# Out:
# 1279914147774443520
# 2020-07-05 23:04:47
# Twitter Web App
# 3
# 1
# None
# None
# {'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'josejoiys', 'name': 'Jose Bascuñan', 'id': 55080173, 'id_str': '55080173', 'indices': [0, 10]}], 'urls': [], 'media': [{'id': 1279914136399482881, 'id_str': '1279914136399482881', 'indices': [11, 34], 'media_url': 'http://pbs.twimg.com/tweet_video_thumb/EcMrIDMXkAECqNB.jpg', 'media_url_https': 'https://pbs.twimg.com/tweet_video_thumb/EcMrIDMXkAECqNB.jpg', 'url': 'https://t.co/1sXNSBZEh1', 'display_url': 'pic.twitter.com/1sXNSBZEh1', 'expanded_url': 'https://twitter.com/PrimeVideoLat/status/1279914147774443520/photo/1', 'type': 'photo', 'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'}, 'large': {'w': 454, 'h': 256, 'resize': 'fit'}, 'small': {'w': 454, 'h': 256, 'resize': 'fit'}, 'medium': {'w': 454, 'h': 256, 'resize': 'fit'}}}]}

# %%
# We add relevant data:
data['len']  = np.array([len(tweet.text) for tweet in tweets])
data['ID']   = np.array([tweet.id for tweet in tweets])
data['Date'] = np.array([tweet.created_at for tweet in tweets])
data['Source'] = np.array([tweet.source for tweet in tweets])
data['Likes']  = np.array([tweet.favorite_count for tweet in tweets])
data['RTs']    = np.array([tweet.retweet_count for tweet in tweets])

# %%
# Display of first 10 elements from dataframe:
display(data.head(10))
# Out:
#                                               Tweets  len  \
# 0                 @josejoiys https://t.co/1sXNSBZEh1   34
# 1            @OmarLeeOficial https://t.co/G3GALkYuUi   39
# 2  @CDarioRodriguez Drama: Little Fires Everywher...  102
# 3           @_salvapantallas https://t.co/j3x7GE08Ax   40
# 4                @SILVAELIAS_ ¿Quien es exactamente?   35
# 5  —¿Cuál es tu sueño?\n—Poder dormir antes de la...  124
# 6                     @jjimmybass ¿la empezamos hoy?   30
# 7           @oleicymar Esa es la mejor respuesta. ❤️   40
# 8                        @guadapavon_ @Deivid_pela 🤩   27
# 9               @AngelitoSvr https://t.co/QLHwQdONrV   36
#
#                     ID                Date           Source  Likes  RTs
# 0  1279914147774443520 2020-07-05 23:04:47  Twitter Web App      3    1
# 1  1279912966104760321 2020-07-05 23:00:05  Twitter Web App      1    0
# 2  1279904492213821440 2020-07-05 22:26:25  Twitter Web App      1    1
# 3  1279901382837927936 2020-07-05 22:14:03  Twitter Web App      1    0
# 4  1279898974263050242 2020-07-05 22:04:29  Twitter Web App      0    0
# 5  1279883500724813829 2020-07-05 21:03:00  Twitter Web App    108   10
# 6  1279815094231281664 2020-07-05 16:31:10  Twitter Web App      1    0
# 7  1279814984437051399 2020-07-05 16:30:44  Twitter Web App      0    0
# 8  1279811492464951296 2020-07-05 16:16:52  Twitter Web App      2    0
# 9  1279811299355082753 2020-07-05 16:16:06  Twitter Web App      1    0

# %%
len(data)
# Out:
# 200

# %%
data.to_excel("Amazon200.xls", index=False)

# %%
# We extract the mean of lenghts:
mean = np.mean(data['len'])

print("The lenght's average in tweets: {}".format(mean))
# Out:
# The lenght's average in tweets: 56.12

# %%
# We extract the tweet with more FAVs and more RTs:

fav_max = np.max(data['Likes'])
rt_max  = np.max(data['RTs'])

fav = data[data.Likes == fav_max].index[0]
rt  = data[data.RTs == rt_max].index[0]

# Max FAVs:
print("The tweet with more likes is: \n{}".format(data['Tweets'][fav]))
print("Number of likes: {}".format(fav_max))
print("{} characters.\n".format(data['len'][fav]))

# Max RTs:
print("The tweet with more retweets is: \n{}".format(data['Tweets'][rt]))
print("Number of retweets: {}".format(rt_max))
print("{} characters.\n".format(data['len'][rt]))
# Out:
# The tweet with more likes is:
# Una tonelada de series y películas favoritas para todos los gustos. Eso son los estrenos de este mes. https://t.co/QbhwKFBKTG
# Number of likes: 1347
# 125 characters.
#
# The tweet with more retweets is:
# Una tonelada de series y películas favoritas para todos los gustos. Eso son los estrenos de este mes. https://t.co/QbhwKFBKTG
# Number of retweets: 200
# 125 characters.

# %%
# We obtain all possible sources:
sources = []
for source in data['Source']:
    if source not in sources:
        sources.append(source)

# We print sources list:
print("Creation of content sources:")
for source in sources:
    print("* {}".format(source))
# Out:
# Creation of content sources:
# * Twitter Web App
# * Twitter Media Studio
# * Twitter for iPhone
# * Sprinklr

# %%
# We create a numpy vector mapped to labels:
percent = np.zeros(len(sources))

for source in data['Source']:
    for index in range(len(sources)):
        if source == sources[index]:
            percent[index] += 1
            pass

percent /= 100

# Pie chart:
pie_chart = pd.Series(percent, index=sources, name='Sources')
pie_chart.plot.pie(fontsize=11, autopct='%.2f', figsize=(6, 6));

# %%
from textblob import TextBlob
import re

def clean_tweet(tweet):
    '''
    Utility function to clean the text in a tweet by removing
    links and special characters using regex.
    '''
    return ' '.join(re.sub("(@[A-Za-z0-9]+)|([^0-9A-Za-z \t])|(\w+:\/\/\S+)", " ", tweet).split())

def analize_sentiment(tweet):
    '''
    Utility function to classify the polarity of a tweet
    using textblob.
    '''
    analysis = TextBlob(clean_tweet(tweet))
    if analysis.sentiment.polarity > 0:
        return 1
    elif analysis.sentiment.polarity == 0:
        return 0
    else:
        return -1

# %%
# We create a column with the result of the analysis:
data['SA'] = np.array([ analize_sentiment(tweet) for tweet in data['Tweets'] ])

# We display the updated dataframe with the new column:
display(data.head(10))
# Out:
#                                               Tweets  len  \
# 0                 @josejoiys https://t.co/1sXNSBZEh1   34
# 1            @OmarLeeOficial https://t.co/G3GALkYuUi   39
# 2  @CDarioRodriguez Drama: Little Fires Everywher...  102
# 3           @_salvapantallas https://t.co/j3x7GE08Ax   40
# 4                @SILVAELIAS_ ¿Quien es exactamente?   35
# 5  —¿Cuál es tu sueño?\n—Poder dormir antes de la...  124
# 6                     @jjimmybass ¿la empezamos hoy?   30
# 7           @oleicymar Esa es la mejor respuesta. ❤️   40
# 8                        @guadapavon_ @Deivid_pela 🤩   27
# 9               @AngelitoSvr https://t.co/QLHwQdONrV   36
#
#                     ID                Date           Source  Likes  RTs  SA
# 0  1279914147774443520 2020-07-05 23:04:47  Twitter Web App      3    1   0
# 1  1279912966104760321 2020-07-05 23:00:05  Twitter Web App      1    0   0
# 2  1279904492213821440 2020-07-05 22:26:25  Twitter Web App      1    1   1
# 3  1279901382837927936 2020-07-05 22:14:03  Twitter Web App      1    0   0
# 4  1279898974263050242 2020-07-05 22:04:29  Twitter Web App      0    0   0
# 5  1279883500724813829 2020-07-05 21:03:00  Twitter Web App    108   10   0
# 6  1279815094231281664 2020-07-05 16:31:10  Twitter Web App      1    0   0
# 7  1279814984437051399 2020-07-05 16:30:44  Twitter Web App      0    0   0
# 8  1279811492464951296 2020-07-05 16:16:52  Twitter Web App      2    0   0
# 9  1279811299355082753 2020-07-05 16:16:06  Twitter Web App      1    0   0

# %% [markdown]
# ANALIZAMOS LOS RESULTADOS

# %%
# We construct lists with classified tweets:

pos_tweets = [ tweet for index, tweet in enumerate(data['Tweets']) if data['SA'][index] > 0]
neu_tweets = [ tweet for index, tweet in enumerate(data['Tweets']) if data['SA'][index] == 0]
neg_tweets = [ tweet for index, tweet in enumerate(data['Tweets']) if data['SA'][index] < 0]

# %%
# We print percentages:

print("Percentage of positive tweets: {}%".format(len(pos_tweets)*100/len(data['Tweets'])))
print("Percentage of neutral tweets: {}%".format(len(neu_tweets)*100/len(data['Tweets'])))
print("Percentage de negative tweets: {}%".format(len(neg_tweets)*100/len(data['Tweets'])))
# Out:
# Percentage of positive tweets: 5.0%
# Percentage of neutral tweets: 93.0%
# Percentage de negative tweets: 2.0%
